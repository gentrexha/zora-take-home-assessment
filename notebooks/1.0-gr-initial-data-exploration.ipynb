# %%
# %matplotlib inline

# %%
import sweetviz as sv
import pandas as pd

# Your data analysis
df_collectors = pd.read_csv('../data/raw/collectors.csv')
report = sv.analyze(df_collectors)
report.show_html('collectors_data_exploration.html')
# Out:
# Feature: wallet_address                      |▊         | [  8%]   00:00 -> (00:00 left)
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# Report data_profile.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from autoviz import AutoViz_Class
AV = AutoViz_Class()

filename = "../data/raw/collectors.csv"
target_variable = "churned_at_date"

dft = AV.AutoViz(
    filename,
    depVar=target_variable,
)
# Out:
# Shape of your Data Set loaded: (1000, 11)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  3
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  3
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  3
#     Number of Columns to Delete =  0
#     10 Predictors classified...
#         3 variable(s) removed since they were ID or low-information variables
# ...

# %%
import sweetviz as sv
import pandas as pd

# Your data analysis
df_collection_activity = pd.read_csv('../data/raw/collection_activity.csv')
report = sv.analyze(df_collection_activity)
report.show_html('collection_activity_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report collection_activity_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
from autoviz import AutoViz_Class
AV = AutoViz_Class()

filename = "../data/raw/collection_activity.csv"

dft = AV.AutoViz(
    filename,
)
# Out:
#     max_rows_analyzed is smaller than dataset shape 645212...
#         randomly sampled 150000 rows from read CSV file
# Shape of your Data Set loaded: (150000, 9)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  2
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  4
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  1
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  2
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     9 Predictors classified...
# ...

# %%
df_collection_activity.head()
# Out:
#                                wallet_address        date file_type  token_id  \
# 0  0x8a01f2c0996ee0dd880d3d5a5ac0ce745fb96843  2023-09-04     video      12.0
# 1  0x8a01f2c0996ee0dd880d3d5a5ac0ce745fb96843  2023-09-05     audio     319.0
# 2  0x8a01f2c0996ee0dd880d3d5a5ac0ce745fb96843  2023-09-05     video      95.0
# 3  0x8a01f2c0996ee0dd880d3d5a5ac0ce745fb96843  2023-09-05       gif     872.0
# 4  0x8a01f2c0996ee0dd880d3d5a5ac0ce745fb96843  2023-09-30     video     864.0
#
#                            collection_address chain_name  number_collected  \
# 0  0xbbedd51cbc7b229361dfdd00e81ee8d6b103ffaf       Base             407.0
# 1  0x525f5786848b39fd81d3866e09d97923c7cdaf52       Zora             121.0
# 2  0xca3f42c44d0a5f10e757e8dc38b76ac128638662   Arbitrum              13.0
# 3  0x71bb68460bfb9ffccd0eaf22dbd690c2daec2e86   Arbitrum             460.0
# 4  0xf093d07e7a53ba798c86500ca8ab0e199ad0dbd7   Arbitrum             857.0
#
# ...

# %%
df_collection_activity.groupby('wallet_address').agg(
    collections_count=('collection_address', 'count'),
    unique_collections=('collection_address', 'nunique'),
    total_collected=('number_collected', 'sum'),
    avg_collected=('number_collected', 'mean'),
    median_collected=('number_collected', 'median'),
    comments_count=('commented', 'count')
)
# Out:
#                                             collections_count  \
# wallet_address
# 0x0094223a09f62bb55acf2df43a78fb91ccac05d0                 81
# 0x00b3d6508db5e725d9748ed6e9307552a35a2389               1172
# 0x00d64a632b8fac343abd4c235724051ccb833242                411
# 0x02113cf39ddf3496d040a88dfe67701a13fe3459                404
# 0x0247fe708bc229c615d9b4975ce5cc9cf17b8c93                660
# ...                                                       ...
# 0xfe928465b0085fef48b0205bc22a95c1047b0282                459
# 0xfee5540aac073c01e41ef50aa3eaa2b75c3d8662                912
# 0xff2e491f9209849105dfdcceb706e30b5b7cedab                550
# 0xff2eebc8e471654c6268be2f23ac21738c593c3f                559
# 0xff60d21e5c90093a8c506c68357594dcc5d6c67e                463
#
#                                             unique_collections  \
# wallet_address
# 0x0094223a09f62bb55acf2df43a78fb91ccac05d0                  81
# ...
